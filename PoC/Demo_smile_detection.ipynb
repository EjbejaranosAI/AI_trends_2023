# %% [markdown]
# <a href="https://colab.research.google.com/github/EjbejaranosAI/AI_trends_2023/blob/main/PoC/Demo_smile_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Smile detection PoC Sprint review

# %% [markdown]
# # Import libraries

# %%
# !pip install -q mediapipe
# !pip install -q streamlit
# !npm install localtunnel
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 35.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 164.8/164.8 kB 13.6 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 16.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 68.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.1/82.1 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 5.6 MB/s eta 0:00:00
#   Building wheel for validators (setup.py) ... done

# %% [markdown]
# # Load model and video

# %%
#predictions
import tensorflow as tf
import matplotlib.pyplot as plt
import time

import os
import cv2
import numpy as np
import mediapipe as mp
from google.colab.patches import cv2_imshow



#General parameters
path_video = "/content/video.mp4"
model = tf.keras.models.load_model("smile_model.h5")
threshold = 0.9


# Functions
def predict_smile(img,plot_image= False):
  face_detection = mp.solutions.face_detection.FaceDetection()
  face = face_detection.process(img)
  detections = face.detections

  for detection in detections:
      bbox = detection.location_data.relative_bounding_box
      h, w, _ = img.shape
      x, y, width, height = int(bbox.xmin * w), int(bbox.ymin * h), int(bbox.width * w), int(bbox.height * h)
      crop_face = img[y:y+height, x:x+width]
      cv2.rectangle(img, (x, y), (x + width, y + height), (0, 255, 0), 2)



  resized_face = cv2.resize(crop_face, (224, 224))

  prediction_smile = model.predict(resized_face.reshape(1, 224, 224, 3))
  prediction_smile_value = np.max(prediction_smile[0])
  prediction_smile_index = np.argmax(prediction_smile)
  print(f"Prediction index {prediction_smile_index}")
  print(f"Prediction value {prediction_smile_value}")

  if plot_image:
    print("Image after reshape")
    plt.imshow(cv2.cvtColor(resized_face, cv2.COLOR_BGR2RGB))
    plt.show()
    plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
    plt.show()
  # Index 0 = not smiling in prediction_smile_index
  if prediction_smile_index==0:
    print("---------------- Not smiling ----------------")
    prediction_value = 0
  else:

    if prediction_smile_value >= threshold:
      prediction_value = 1
      print("---------------- Smiling ----------------")
    else:
      prediction_value = 0
      print("---------------- Not smiling ----------------")

  return prediction_value





def extract_video_segments(video_path, time_length, contnue_results=True):
    tic = time.time()

    cap = cv2.VideoCapture(video_path)
    fps = cap.get(cv2.CAP_PROP_FPS)
    total_frames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
    print(f"Total frames: {total_frames}")
    print(f"FPS: {fps}")
    try:
        video_length = int(total_frames)/int(fps)
        print(f"Video length: {video_length} seconds")
    except ZeroDivisionError:
        print("Could not get video length")

    # Calculate the frame indices for the start and end segments
    start_frames = int(fps * time_length)
    end_frames = int(total_frames - fps * time_length)
    init_pred = []
    final_pred = []

    video_start = []
    video_end = []
    for frame_num in range(int(total_frames)):
        ret, frame = cap.read()
        if not ret:
            break
        if frame_num < start_frames:
            init_pred.append(predict_smile(frame))
            video_start.append(frame)
        if frame_num > end_frames:
            final_pred.append(predict_smile(frame))
            video_end.append(frame)

    cap.release()

    # Save the extracted video segments
    output_path_start = os.path.join(os.path.dirname(video_path), "start_segment.mp4")
    output_path_end = os.path.join(os.path.dirname(video_path), "end_segment.mp4")

    save_video(output_path_start, video_start, fps)
    save_video(output_path_end, video_end, fps)

    if contnue_results:
      print("------------------ Continuous analysis ------------------\n\n")
      #Processing results to detect continuos positive predictions
      print(f"For the first {time_length} seconds of the video the result is: ")
      general_init_pred = is_continuous_ones(init_pred)
      print(f"\nFor the last {time_length} of the video the result is: ")
      general_final_pred = is_continuous_ones(final_pred)

    else:
      print("------------------ General analysis ------------------")
      # Processing results to detect smilling through the video
      print(f"For the first {time_length} seconds of the video the result is: ")
      general_init_pred = procesing_results(init_pred)

      print(f"\nFor the last {time_length} of the video the result is: ")
      general_final_pred = procesing_results(final_pred)


    toc = time.time()
    print(toc-tic)
    return init_pred, final_pred



def save_video(output_path, frames, fps):
    height, width, _ = frames[0].shape
    fourcc = cv2.VideoWriter_fourcc(*"mp4v")
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
    for frame in frames:
        out.write(frame)
    out.release()


def is_continuous_ones(arr):
    ones_count = 0
    for num in arr:
        if num == 1:
            ones_count += 1
            if ones_count >= 10:

                print("For this segment of the video IS smiling")
                general_prediction = 1
                return general_prediction
        else:
            #print("not smilling")
            general_prediction = 0
    if general_prediction ==0:
        print("For this segment of the video IS NOT smiling")
    return general_prediction


def procesing_results(results):

  start_len = len(results)

  smiles_sum_start = np.sum(start)
  if smiles_sum_start >= start_len/3:
    print("For this segment of the video is smiling :) ")
    general_prediction = 1
    return general_prediction
  else:
    print("For this segment of the video IS NOT smiling")
    general_prediction = 0
    return general_prediction

# %%
start, end = extract_video_segments(path_video,10)
# Out:
# Total frames: 1371.0
# FPS: 24.0
# Video length: 57.125 seconds
# 1/1 [==============================] - 1s 954ms/step
# Prediction index 1
# Prediction value 0.6849311590194702
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.743406355381012
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.547702431678772
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.7491965293884277
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.7085261344909668
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.7040334343910217
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5570223331451416
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 1
# Prediction value 0.8175230622291565
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.5957059860229492
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.9308300614356995
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 0
# Prediction value 0.6430653929710388
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 117ms/step
# Prediction index 0
# Prediction value 0.6407577395439148
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 110ms/step
# Prediction index 1
# Prediction value 0.7161126732826233
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 1
# Prediction value 0.5218492746353149
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.8021542429924011
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 1
# Prediction value 0.873516321182251
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.9063386917114258
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 123ms/step
# Prediction index 1
# Prediction value 0.7315659523010254
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 1
# Prediction value 0.6610456109046936
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 0
# Prediction value 0.5205780863761902
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 119ms/step
# Prediction index 1
# Prediction value 0.699297308921814
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 1
# Prediction value 0.8048167824745178
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 0
# Prediction value 0.5612454414367676
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 130ms/step
# Prediction index 1
# Prediction value 0.8423267006874084
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.8886670470237732
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 99ms/step
# Prediction index 1
# Prediction value 0.938470721244812
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.6915926337242126
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.8573636412620544
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.8839131593704224
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.9297551512718201
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 1
# Prediction value 0.9666397571563721
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.9076964855194092
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.9594006538391113
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.6342228055000305
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.8515294194221497
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.9591425657272339
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.9240285158157349
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.6695582270622253
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7557865381240845
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 81ms/step
# Prediction index 1
# Prediction value 0.9487031698226929
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.8742936253547668
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.810868501663208
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.644110381603241
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5095373392105103
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.5925122499465942
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.5809641480445862
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.5801302790641785
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.7632303833961487
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8647063374519348
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 77ms/step
# Prediction index 1
# Prediction value 0.870167076587677
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.9715574979782104
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.9849281907081604
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 1
# Prediction value 0.6942583322525024
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.804179847240448
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.9310357570648193
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 0
# Prediction value 0.708601713180542
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.7798559665679932
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.515091061592102
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.7422411441802979
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.7033782005310059
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.5301505923271179
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.9356201887130737
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.9203957319259644
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.8505308628082275
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.5447704792022705
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.813141942024231
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.8996421694755554
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.6137375831604004
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.8298473954200745
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.8726766109466553
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.500396192073822
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.7545678019523621
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 1
# Prediction value 0.9556766152381897
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.766298234462738
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.6114576458930969
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.5488832592964172
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5190668106079102
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8225076794624329
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.6979773044586182
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.6388054490089417
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.6851353645324707
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.6599074006080627
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.6077863574028015
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 0
# Prediction value 0.6773464679718018
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.8483298420906067
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.902182936668396
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.6363717317581177
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.9126307368278503
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.841816782951355
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.6016124486923218
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.7064976096153259
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8289235830307007
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 1
# Prediction value 0.6716209650039673
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8390272855758667
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 1
# Prediction value 0.6439893841743469
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.6526614427566528
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.9527487754821777
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 96ms/step
# Prediction index 1
# Prediction value 0.6516638994216919
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.7362467646598816
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 0
# Prediction value 0.8353965878486633
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 123ms/step
# Prediction index 1
# Prediction value 0.5814682841300964
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 101ms/step
# Prediction index 0
# Prediction value 0.6683346033096313
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 114ms/step
# Prediction index 0
# Prediction value 0.6435430645942688
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 0
# Prediction value 0.5688696503639221
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 99ms/step
# Prediction index 0
# Prediction value 0.5363448858261108
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 1
# Prediction value 0.540308952331543
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 116ms/step
# Prediction index 1
# Prediction value 0.7907382249832153
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 0
# Prediction value 0.597114622592926
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 1
# Prediction value 0.5702932476997375
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 0
# Prediction value 0.5548030734062195
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 112ms/step
# Prediction index 0
# Prediction value 0.6641022562980652
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 112ms/step
# Prediction index 1
# Prediction value 0.8941259384155273
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 108ms/step
# Prediction index 1
# Prediction value 0.8367260694503784
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 0
# Prediction value 0.6471335291862488
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.650941014289856
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 113ms/step
# Prediction index 1
# Prediction value 0.949736475944519
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.8084834218025208
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.9625068306922913
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.5153471827507019
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.5546995401382446
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 1
# Prediction value 0.7177057862281799
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.8721397519111633
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.6375441551208496
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.5161564946174622
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.53518146276474
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7589043378829956
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.7762662172317505
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.768795907497406
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5245897173881531
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.637310266494751
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.7413108348846436
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.6494496464729309
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7656508684158325
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.6430696249008179
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.8002673387527466
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.6074033975601196
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 90ms/step
# Prediction index 1
# Prediction value 0.7261397242546082
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.749428391456604
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.5572869181632996
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.6604501008987427
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.5320388078689575
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8815513253211975
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.9096589088439941
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.8726046085357666
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9404934644699097
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.7919408679008484
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.6203495860099792
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.5071097016334534
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.7322124242782593
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.7349050045013428
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5403932929039001
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 0
# Prediction value 0.9087175726890564
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.8922578692436218
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.7042973637580872
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.7056784629821777
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.6716421246528625
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.8617210388183594
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.5191118717193604
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 80ms/step
# Prediction index 1
# Prediction value 0.7511799335479736
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.9804204702377319
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.5557674765586853
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.8489207625389099
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.7754508852958679
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.8276933431625366
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.8177056908607483
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.9153611063957214
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.8008327484130859
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.549496591091156
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 1
# Prediction value 0.7917786240577698
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.6282260417938232
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.6293030381202698
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.8783830404281616
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.8020981550216675
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.5047218799591064
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5353493690490723
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 0
# Prediction value 0.8623288869857788
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.9578539133071899
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.9488072395324707
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 181ms/step
# Prediction index 0
# Prediction value 0.6052640676498413
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.5328608751296997
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.555696427822113
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 0
# Prediction value 0.9645078182220459
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 190ms/step
# Prediction index 0
# Prediction value 0.9848004579544067
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 204ms/step
# Prediction index 0
# Prediction value 0.9815564155578613
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 0
# Prediction value 0.9620509147644043
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 114ms/step
# Prediction index 0
# Prediction value 0.5410932898521423
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 429ms/step
# Prediction index 0
# Prediction value 0.5125046968460083
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 0
# Prediction value 0.7695846557617188
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 101ms/step
# Prediction index 0
# Prediction value 0.7466903924942017
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 120ms/step
# Prediction index 1
# Prediction value 0.6621002554893494
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 0
# Prediction value 0.7766976952552795
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 108ms/step
# Prediction index 0
# Prediction value 0.9257796406745911
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 116ms/step
# Prediction index 0
# Prediction value 0.7889777421951294
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 0
# Prediction value 0.9834271669387817
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 0
# Prediction value 0.9722462892532349
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 120ms/step
# Prediction index 0
# Prediction value 0.8377895951271057
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 114ms/step
# Prediction index 0
# Prediction value 0.5794243812561035
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 1
# Prediction value 0.7720203399658203
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7346362471580505
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.7745391726493835
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.7006010413169861
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.9121872186660767
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.9340461492538452
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.9010796546936035
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.783794105052948
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 0
# Prediction value 0.7351897358894348
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.9700671434402466
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.9067549109458923
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9375532865524292
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.5190893411636353
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.7583506107330322
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.6742932200431824
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.6961491107940674
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.619284987449646
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 0
# Prediction value 0.8263538479804993
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.8273588418960571
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.520751416683197
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.8000229001045227
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 1
# Prediction value 0.532047688961029
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.6163987517356873
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.7515278458595276
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.994140088558197
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8270425200462341
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7936338186264038
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8496545553207397
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.6915378570556641
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 80ms/step
# Prediction index 1
# Prediction value 0.9806872010231018
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.5762792825698853
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.8154581189155579
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.9055565595626831
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.6482899188995361
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.7590638995170593
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.5291588306427002
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.7675346732139587
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.8724436163902283
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.599780261516571
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.6925073862075806
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.5141471028327942
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.9116839170455933
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 1
# Prediction value 0.5018900632858276
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5947832465171814
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.7049311995506287
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.5987961888313293
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.9320017099380493
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8410144448280334
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.8472175598144531
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.6891579031944275
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.7665356397628784
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.9155118465423584
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.6280044317245483
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.8414524793624878
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.866850733757019
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 110ms/step
# Prediction index 1
# Prediction value 0.5225343704223633
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 108ms/step
# Prediction index 1
# Prediction value 0.9209709763526917
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 127ms/step
# Prediction index 0
# Prediction value 0.5687753558158875
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 112ms/step
# Prediction index 1
# Prediction value 0.8399698734283447
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.9707768559455872
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 107ms/step
# Prediction index 1
# Prediction value 0.826865553855896
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 100ms/step
# Prediction index 1
# Prediction value 0.7149889469146729
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 1
# Prediction value 0.9269919395446777
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 108ms/step
# Prediction index 1
# Prediction value 0.6471357941627502
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 107ms/step
# Prediction index 0
# Prediction value 0.5256975293159485
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 1
# Prediction value 0.5304292440414429
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 99ms/step
# Prediction index 1
# Prediction value 0.9054642915725708
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 101ms/step
# Prediction index 1
# Prediction value 0.653135359287262
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 0
# Prediction value 0.6317182183265686
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 93ms/step
# Prediction index 1
# Prediction value 0.5656062960624695
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 1
# Prediction value 0.7551571726799011
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.718227207660675
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.7089937329292297
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.7426537275314331
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.7513504028320312
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.865009069442749
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.7393840551376343
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.9131954312324524
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.5226580500602722
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.574481189250946
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.7191070914268494
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.6406130194664001
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.8304764628410339
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 58ms/step
# Prediction index 0
# Prediction value 0.57920902967453
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.5238341689109802
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.7885144948959351
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.6994314193725586
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.8975743651390076
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.7906581163406372
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.9461891055107117
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.9838115572929382
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.714783787727356
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.9627165794372559
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.6390736103057861
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.9923713207244873
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.9096492528915405
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.9756609797477722
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.5652429461479187
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9662082195281982
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.947615385055542
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.9516679048538208
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.9120025634765625
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.9311061501502991
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.955978274345398
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.5026671290397644
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.7921943664550781
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 0
# Prediction value 0.9457225203514099
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.9766057729721069
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.9690923690795898
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.9950157999992371
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.9927785992622375
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.9257161021232605
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.9338634610176086
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 81ms/step
# Prediction index 0
# Prediction value 0.8695312738418579
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.9140588641166687
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.9325421452522278
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 0
# Prediction value 0.570750892162323
# ---------------- Not smiling ----------------
# ...
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.9552822113037109
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 59ms/step
# Prediction index 1
# Prediction value 0.9771464467048645
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.8929134011268616
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8139398097991943
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.9083925485610962
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 81ms/step
# Prediction index 1
# Prediction value 0.9145073890686035
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8621706366539001
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.6327010989189148
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.8671041131019592
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 77ms/step
# Prediction index 1
# Prediction value 0.9386152029037476
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.9522577524185181
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8172563314437866
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.5218313336372375
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.8971487283706665
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.652633547782898
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 77ms/step
# Prediction index 1
# Prediction value 0.7672814726829529
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 1
# Prediction value 0.8956812024116516
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.657214343547821
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.9627425670623779
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 1
# Prediction value 0.9226906895637512
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.6202636361122131
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 1
# Prediction value 0.7499067187309265
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 89ms/step
# Prediction index 1
# Prediction value 0.5438206791877747
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 77ms/step
# Prediction index 1
# Prediction value 0.692555844783783
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.91510009765625
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.9300752282142639
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.7232656478881836
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.7108404040336609
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.58955317735672
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.6871183514595032
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.8809080123901367
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.571148157119751
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 80ms/step
# Prediction index 1
# Prediction value 0.9384876489639282
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.7032885551452637
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.9032723307609558
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.5601595640182495
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.7027072310447693
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.5704370737075806
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.7670367956161499
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.6223242878913879
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.7177062630653381
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7729713916778564
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.5096940994262695
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 88ms/step
# Prediction index 0
# Prediction value 0.5090249180793762
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 100ms/step
# Prediction index 1
# Prediction value 0.8310816287994385
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 1
# Prediction value 0.8996475338935852
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 100ms/step
# Prediction index 1
# Prediction value 0.9154376983642578
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 1
# Prediction value 0.9053401947021484
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 1
# Prediction value 0.6339779496192932
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 1
# Prediction value 0.7972573637962341
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 116ms/step
# Prediction index 0
# Prediction value 0.6990476250648499
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 0
# Prediction value 0.9741361737251282
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 99ms/step
# Prediction index 0
# Prediction value 0.7998713850975037
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 0
# Prediction value 0.5000404119491577
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 118ms/step
# Prediction index 0
# Prediction value 0.9251983761787415
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 0
# Prediction value 0.5721145868301392
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 0
# Prediction value 0.9125209450721741
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 112ms/step
# Prediction index 0
# Prediction value 0.7643842697143555
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 118ms/step
# Prediction index 0
# Prediction value 0.5674942135810852
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 0
# Prediction value 0.6898502707481384
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 1
# Prediction value 0.5360363125801086
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 97ms/step
# Prediction index 1
# Prediction value 0.576057493686676
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 59ms/step
# Prediction index 1
# Prediction value 0.6681339144706726
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.7205735445022583
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8777775168418884
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.6983803510665894
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5875058174133301
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.7481902837753296
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.7192578315734863
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.5025233626365662
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.6352062225341797
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.7186663746833801
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.6314536333084106
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.5703787207603455
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.6003865599632263
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.6037194132804871
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.7821934819221497
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.7488706707954407
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.7957987189292908
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.6319966912269592
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.5337711572647095
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.9261901378631592
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.8423454165458679
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.5967068672180176
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.8564782738685608
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.5708338618278503
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.7574892044067383
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9012110829353333
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.7290588617324829
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.8008275628089905
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.9735459089279175
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.9112395644187927
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.7834450006484985
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.5472795963287354
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.6320330500602722
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.7296401262283325
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.9384695887565613
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.7306175231933594
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.7119829654693604
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.5533300042152405
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.792218029499054
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.9171172380447388
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.710691511631012
# ---------------- Not smiling ----------------
# ------------------ Continuous analysis ------------------
#
#
# For the first 10 seconds of the video the result is:
# For this segment of the video IS smiling
#
# For the last 10 of the video the result is:
# For this segment of the video IS smiling
# 86.2852771282196

# %%
import tensorflow as tf
import matplotlib.pyplot as plt
import time
import os
import cv2
import numpy as np
import mediapipe as mp
from google.colab.patches import cv2_imshow


class SmileDetectionAnalyzer:
    def __init__(self, model_path, threshold=0.9):
        self.model = tf.keras.models.load_model(model_path)
        self.threshold = threshold

    def predict_smile(self, img, plot_image=False):
        face_detection = mp.solutions.face_detection.FaceDetection()
        face = face_detection.process(img)
        detections = face.detections

        for detection in detections:
            bbox = detection.location_data.relative_bounding_box
            h, w, _ = img.shape
            x, y, width, height = int(bbox.xmin * w), int(bbox.ymin * h), int(bbox.width * w), int(bbox.height * h)
            crop_face = img[y:y + height, x:x + width]
            cv2.rectangle(img, (x, y), (x + width, y + height), (0, 255, 0), 2)

        resized_face = cv2.resize(crop_face, (224, 224))

        prediction_smile = self.model.predict(resized_face.reshape(1, 224, 224, 3))
        prediction_smile_value = np.max(prediction_smile[0])
        prediction_smile_index = np.argmax(prediction_smile)
        print(f"Prediction index {prediction_smile_index}")
        print(f"Prediction value {prediction_smile_value}")

        if plot_image:
            print("Image after reshape")
            plt.imshow(cv2.cvtColor(resized_face, cv2.COLOR_BGR2RGB))
            plt.show()
            plt.imshow(cv2.cvtColor(img, cv2.COLOR_BGR2RGB))
            plt.show()

        if prediction_smile_index == 0:
            print("---------------- Not smiling ----------------")
            prediction_value = 0
        else:
            if prediction_smile_value >= self.threshold:
                prediction_value = 1
                print("---------------- Smiling ----------------")
            else:
                prediction_value = 0
                print("---------------- Not smiling ----------------")

        return prediction_value

    @staticmethod
    def save_video(output_path, frames, fps):
        height, width, _ = frames[0].shape
        fourcc = cv2.VideoWriter_fourcc(*"mp4v")
        out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        for frame in frames:
            out.write(frame)
        out.release()

    @staticmethod
    def is_continuous_ones(arr):
        ones_count = 0
        for num in arr:
            if num == 1:
                ones_count += 1
                if ones_count >= 10:
                    print("For this segment of the video IS smiling")
                    general_prediction = 1
                    return general_prediction
            else:
                general_prediction = 0
        if general_prediction == 0:
            print("For this segment of the video IS NOT smiling")
        return general_prediction

    @staticmethod
    def processing_results(results):
        start_len = len(results)
        smiles_sum_start = np.sum(results)
        if smiles_sum_start >= start_len / 3:
            print("For this segment of the video is smiling :) ")
            general_prediction = 1
        else:
            print("For this segment of the video IS NOT smiling")
            general_prediction = 0
        return general_prediction

    def extract_video_segments(self, video_path, time_length, continue_results=True):
        tic = time.time()

        cap = cv2.VideoCapture(video_path)
        fps = cap.get(cv2.CAP_PROP_FPS)
        total_frames = cap.get(cv2.CAP_PROP_FRAME_COUNT)
        print(f"Total frames: {total_frames}")
        print(f"FPS: {fps}")
        try:
            video_length = int(total_frames) / int(fps)
            print(f"Video length: {video_length} seconds")
        except ZeroDivisionError:
            print("Could not get video length")

        start_frames = int(fps * time_length)
        end_frames = int(total_frames - fps * time_length)
        init_pred = []
        final_pred = []
        video_start = []
        video_end = []

        for frame_num in range(int(total_frames)):
            ret, frame = cap.read()
            if not ret:
                break
            if frame_num < start_frames:
                init_pred.append(self.predict_smile(frame))
                video_start.append(frame)
            if frame_num > end_frames:
                final_pred.append(self.predict_smile(frame))
                video_end.append(frame)

        cap.release()

        output_path_start = os.path.join(os.path.dirname(video_path), "start_segment.mp4")
        output_path_end = os.path.join(os.path.dirname(video_path), "end_segment.mp4")

        self.save_video(output_path_start, video_start, fps)
        self.save_video(output_path_end, video_end, fps)

        if continue_results:
            print("------------------ Continuous analysis ------------------\n\n")
            print(f"For the first {time_length} seconds of the video the result is: ")
            general_init_pred = self.is_continuous_ones(init_pred)
            print(f"\nFor the last {time_length} of the video the result is: ")
            general_final_pred = self.is_continuous_ones(final_pred)
        else:
            print("------------------ General analysis ------------------")
            print(f"For the first {time_length} seconds of the video the result is: ")
            general_init_pred = self.processing_results(init_pred)
            print(f"\nFor the last {time_length} of the video the result is: ")
            general_final_pred = self.processing_results(final_pred)

        toc = time.time()
        print(toc - tic)
        return init_pred, final_pred
analyzer = SmileDetectionAnalyzer(model_path="smile_model.h5", threshold=0.9)

init_pred, final_pred = analyzer.extract_video_segments(video_path="/content/video.mp4", time_length=10, continue_results=True)
# Out:
# Total frames: 1371.0
# FPS: 24.0
# Video length: 57.125 seconds
# 1/1 [==============================] - 1s 544ms/step
# Prediction index 1
# Prediction value 0.6849311590194702
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.743406355381012
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.547702431678772
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.7491965293884277
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7085261344909668
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.7040334343910217
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5570223331451416
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.8175230622291565
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.5957059860229492
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.9308300614356995
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.6430653929710388
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.6407577395439148
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7161126732826233
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.5218492746353149
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.8021542429924011
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.873516321182251
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.9063386917114258
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.7315659523010254
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.6610456109046936
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5205780863761902
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.699297308921814
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.8048167824745178
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.5612454414367676
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.8423267006874084
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.8886670470237732
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.938470721244812
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.6915926337242126
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.8573636412620544
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.8839131593704224
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 1
# Prediction value 0.9297551512718201
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.9666397571563721
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.9076964855194092
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.9594006538391113
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.6342228055000305
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8515294194221497
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.9591425657272339
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.9240285158157349
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.6695582270622253
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.7557865381240845
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.9487031698226929
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.8742936253547668
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.810868501663208
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.644110381603241
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.5095373392105103
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.5925122499465942
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.5809641480445862
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5801302790641785
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.7632303833961487
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.8647063374519348
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 59ms/step
# Prediction index 1
# Prediction value 0.870167076587677
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.9715574979782104
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.9849281907081604
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 82ms/step
# Prediction index 1
# Prediction value 0.6942583322525024
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 94ms/step
# Prediction index 1
# Prediction value 0.804179847240448
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 121ms/step
# Prediction index 1
# Prediction value 0.9310357570648193
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 0
# Prediction value 0.708601713180542
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 1
# Prediction value 0.7798559665679932
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 100ms/step
# Prediction index 0
# Prediction value 0.515091061592102
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 99ms/step
# Prediction index 1
# Prediction value 0.7422411441802979
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 1
# Prediction value 0.7033782005310059
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 120ms/step
# Prediction index 1
# Prediction value 0.5301505923271179
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 1
# Prediction value 0.9356201887130737
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 100ms/step
# Prediction index 1
# Prediction value 0.9203957319259644
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 113ms/step
# Prediction index 1
# Prediction value 0.8505308628082275
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 0
# Prediction value 0.5447704792022705
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.813141942024231
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 109ms/step
# Prediction index 1
# Prediction value 0.8996421694755554
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 96ms/step
# Prediction index 0
# Prediction value 0.6137375831604004
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 101ms/step
# Prediction index 1
# Prediction value 0.8298473954200745
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 99ms/step
# Prediction index 0
# Prediction value 0.8726766109466553
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 1
# Prediction value 0.500396192073822
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 100ms/step
# Prediction index 1
# Prediction value 0.7545678019523621
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.9556766152381897
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.766298234462738
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.6114576458930969
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 0
# Prediction value 0.5488832592964172
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.5190668106079102
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.8225076794624329
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 1
# Prediction value 0.6979773044586182
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.6388054490089417
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.6851353645324707
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.6599074006080627
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 1
# Prediction value 0.6077863574028015
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.6773464679718018
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.8483298420906067
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 0
# Prediction value 0.902182936668396
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.6363717317581177
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.9126307368278503
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.841816782951355
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.6016124486923218
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.7064976096153259
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 1
# Prediction value 0.8289235830307007
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.6716209650039673
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8390272855758667
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 1
# Prediction value 0.6439893841743469
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 1
# Prediction value 0.6526614427566528
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.9527487754821777
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.6516638994216919
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.7362467646598816
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.8353965878486633
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.5814682841300964
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.6683346033096313
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.6435430645942688
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.5688696503639221
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.5363448858261108
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.540308952331543
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.7907382249832153
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.597114622592926
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.5702932476997375
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5548030734062195
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.6641022562980652
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8941259384155273
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.8367260694503784
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.6471335291862488
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.650941014289856
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 1
# Prediction value 0.949736475944519
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8084834218025208
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.9625068306922913
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.5153471827507019
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.5546995401382446
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.7177057862281799
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8721397519111633
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.6375441551208496
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.5161564946174622
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.53518146276474
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.7589043378829956
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.7762662172317505
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.768795907497406
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.5245897173881531
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.637310266494751
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.7413108348846436
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.6494496464729309
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.7656508684158325
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.6430696249008179
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.8002673387527466
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.6074033975601196
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.7261397242546082
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.749428391456604
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5572869181632996
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.6604501008987427
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.5320388078689575
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8815513253211975
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.9096589088439941
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.8726046085357666
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 107ms/step
# Prediction index 0
# Prediction value 0.9404934644699097
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 116ms/step
# Prediction index 0
# Prediction value 0.7919408679008484
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 101ms/step
# Prediction index 0
# Prediction value 0.6203495860099792
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 112ms/step
# Prediction index 0
# Prediction value 0.5071097016334534
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.7322124242782593
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 116ms/step
# Prediction index 0
# Prediction value 0.7349050045013428
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 113ms/step
# Prediction index 0
# Prediction value 0.5403932929039001
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 0
# Prediction value 0.9087175726890564
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 0
# Prediction value 0.8922578692436218
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 114ms/step
# Prediction index 0
# Prediction value 0.7042973637580872
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 118ms/step
# Prediction index 1
# Prediction value 0.7056784629821777
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 126ms/step
# Prediction index 1
# Prediction value 0.6716421246528625
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 124ms/step
# Prediction index 0
# Prediction value 0.8617210388183594
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 0
# Prediction value 0.5191118717193604
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 125ms/step
# Prediction index 1
# Prediction value 0.7511799335479736
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 118ms/step
# Prediction index 0
# Prediction value 0.9804204702377319
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 161ms/step
# Prediction index 0
# Prediction value 0.5557674765586853
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 117ms/step
# Prediction index 0
# Prediction value 0.8489207625389099
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7754508852958679
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 82ms/step
# Prediction index 0
# Prediction value 0.8276933431625366
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.8177056908607483
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.9153611063957214
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.8008327484130859
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 1
# Prediction value 0.549496591091156
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.7917786240577698
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.6282260417938232
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.6293030381202698
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.8783830404281616
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 77ms/step
# Prediction index 1
# Prediction value 0.8020981550216675
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.5047218799591064
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5353493690490723
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.8623288869857788
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.9578539133071899
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 81ms/step
# Prediction index 0
# Prediction value 0.9488072395324707
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.6052640676498413
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.5328608751296997
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.555696427822113
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.9645078182220459
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.9848004579544067
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.9815564155578613
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.9620509147644043
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5410932898521423
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.5125046968460083
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7695846557617188
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7466903924942017
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.6621002554893494
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.7766976952552795
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.9257796406745911
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.7889777421951294
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.9834271669387817
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.9722462892532349
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.8377895951271057
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.5794243812561035
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7720203399658203
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.7346362471580505
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.7745391726493835
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.7006010413169861
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9121872186660767
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.9340461492538452
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.9010796546936035
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.783794105052948
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7351897358894348
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.9700671434402466
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9067549109458923
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.9375532865524292
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.5190893411636353
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.7583506107330322
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.6742932200431824
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 81ms/step
# Prediction index 0
# Prediction value 0.6961491107940674
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 76ms/step
# Prediction index 1
# Prediction value 0.619284987449646
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.8263538479804993
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.8273588418960571
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.520751416683197
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8000229001045227
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.532047688961029
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.6163987517356873
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.7515278458595276
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 87ms/step
# Prediction index 1
# Prediction value 0.994140088558197
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.8270425200462341
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7936338186264038
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.8496545553207397
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.6915378570556641
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.9806872010231018
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.5762792825698853
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.8154581189155579
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.9055565595626831
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.6482899188995361
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 96ms/step
# Prediction index 0
# Prediction value 0.7590638995170593
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 1
# Prediction value 0.5291588306427002
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 102ms/step
# Prediction index 1
# Prediction value 0.7675346732139587
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 116ms/step
# Prediction index 1
# Prediction value 0.8724436163902283
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 121ms/step
# Prediction index 0
# Prediction value 0.599780261516571
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 101ms/step
# Prediction index 0
# Prediction value 0.6925073862075806
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 1
# Prediction value 0.5141471028327942
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 115ms/step
# Prediction index 0
# Prediction value 0.9116839170455933
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 1
# Prediction value 0.5018900632858276
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5947832465171814
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.7049311995506287
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.5987961888313293
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.9320017099380493
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8410144448280334
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8472175598144531
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.6891579031944275
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.7665356397628784
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.9155118465423584
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 1
# Prediction value 0.6280044317245483
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.8414524793624878
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.866850733757019
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.5225343704223633
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.9209709763526917
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.5687753558158875
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.8399698734283447
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 78ms/step
# Prediction index 1
# Prediction value 0.9707768559455872
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.826865553855896
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.7149889469146729
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.9269919395446777
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.6471357941627502
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.5256975293159485
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 86ms/step
# Prediction index 1
# Prediction value 0.5304292440414429
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 83ms/step
# Prediction index 1
# Prediction value 0.9054642915725708
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.653135359287262
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.6317182183265686
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.5656062960624695
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.7551571726799011
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.718227207660675
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7089937329292297
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 0
# Prediction value 0.7426537275314331
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.7513504028320312
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.865009069442749
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.7393840551376343
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.9131954312324524
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.5226580500602722
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.574481189250946
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 0
# Prediction value 0.7191070914268494
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.6406130194664001
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.8304764628410339
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.57920902967453
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 1
# Prediction value 0.5238341689109802
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.7885144948959351
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.6994314193725586
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 60ms/step
# Prediction index 0
# Prediction value 0.8975743651390076
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.7906581163406372
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.9461891055107117
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.9838115572929382
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.714783787727356
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.9627165794372559
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.6390736103057861
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.9923713207244873
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.9096492528915405
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 0
# Prediction value 0.9756609797477722
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.5652429461479187
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.9662082195281982
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.947615385055542
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.9516679048538208
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 0
# Prediction value 0.9120025634765625
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 109ms/step
# Prediction index 0
# Prediction value 0.9311061501502991
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 0
# Prediction value 0.955978274345398
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 107ms/step
# Prediction index 0
# Prediction value 0.5026671290397644
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 110ms/step
# Prediction index 0
# Prediction value 0.7921943664550781
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 0
# Prediction value 0.9457225203514099
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 0
# Prediction value 0.9766057729721069
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 104ms/step
# Prediction index 0
# Prediction value 0.9690923690795898
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 101ms/step
# Prediction index 0
# Prediction value 0.9950157999992371
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 0
# Prediction value 0.9927785992622375
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 0
# Prediction value 0.9257161021232605
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 121ms/step
# Prediction index 0
# Prediction value 0.9338634610176086
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 124ms/step
# Prediction index 0
# Prediction value 0.8695312738418579
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 107ms/step
# Prediction index 0
# Prediction value 0.9140588641166687
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 122ms/step
# Prediction index 0
# Prediction value 0.9325421452522278
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 96ms/step
# Prediction index 0
# Prediction value 0.570750892162323
# ---------------- Not smiling ----------------
# ...
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.9552822113037109
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.9771464467048645
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.8929134011268616
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8139398097991943
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 1
# Prediction value 0.9083925485610962
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.9145073890686035
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8621706366539001
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 1
# Prediction value 0.6327010989189148
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.8671041131019592
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.9386152029037476
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 99ms/step
# Prediction index 1
# Prediction value 0.9522577524185181
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 1
# Prediction value 0.8172563314437866
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 121ms/step
# Prediction index 0
# Prediction value 0.5218313336372375
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 119ms/step
# Prediction index 1
# Prediction value 0.8971487283706665
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 105ms/step
# Prediction index 1
# Prediction value 0.652633547782898
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 113ms/step
# Prediction index 1
# Prediction value 0.7672814726829529
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 127ms/step
# Prediction index 1
# Prediction value 0.8956812024116516
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 118ms/step
# Prediction index 1
# Prediction value 0.657214343547821
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 103ms/step
# Prediction index 1
# Prediction value 0.9627425670623779
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 113ms/step
# Prediction index 1
# Prediction value 0.9226906895637512
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 110ms/step
# Prediction index 1
# Prediction value 0.6202636361122131
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 1
# Prediction value 0.7499067187309265
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 96ms/step
# Prediction index 1
# Prediction value 0.5438206791877747
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.692555844783783
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 100ms/step
# Prediction index 1
# Prediction value 0.91510009765625
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 98ms/step
# Prediction index 1
# Prediction value 0.9300752282142639
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 119ms/step
# Prediction index 1
# Prediction value 0.7232656478881836
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 108ms/step
# Prediction index 1
# Prediction value 0.7108404040336609
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 111ms/step
# Prediction index 0
# Prediction value 0.58955317735672
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 106ms/step
# Prediction index 1
# Prediction value 0.6871183514595032
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 1
# Prediction value 0.8809080123901367
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.571148157119751
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.9384876489639282
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.7032885551452637
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.9032723307609558
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 0
# Prediction value 0.5601595640182495
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.7027072310447693
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 80ms/step
# Prediction index 0
# Prediction value 0.5704370737075806
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 0
# Prediction value 0.7670367956161499
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.6223242878913879
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.7177062630653381
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.7729713916778564
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 0
# Prediction value 0.5096940994262695
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.5090249180793762
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.8310816287994385
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 1
# Prediction value 0.8996475338935852
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.9154376983642578
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.9053401947021484
# ---------------- Smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 1
# Prediction value 0.6339779496192932
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 71ms/step
# Prediction index 1
# Prediction value 0.7972573637962341
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.6990476250648499
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.9741361737251282
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.7998713850975037
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.5000404119491577
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9251983761787415
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.5721145868301392
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.9125209450721741
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 0
# Prediction value 0.7643842697143555
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 0
# Prediction value 0.5674942135810852
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.6898502707481384
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 80ms/step
# Prediction index 1
# Prediction value 0.5360363125801086
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 1
# Prediction value 0.576057493686676
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 70ms/step
# Prediction index 1
# Prediction value 0.6681339144706726
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.7205735445022583
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 1
# Prediction value 0.8777775168418884
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.6983803510665894
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 68ms/step
# Prediction index 0
# Prediction value 0.5875058174133301
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 82ms/step
# Prediction index 0
# Prediction value 0.7481902837753296
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 1
# Prediction value 0.7192578315734863
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.5025233626365662
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 75ms/step
# Prediction index 1
# Prediction value 0.6352062225341797
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 59ms/step
# Prediction index 1
# Prediction value 0.7186663746833801
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.6314536333084106
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.5703787207603455
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.6003865599632263
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 0
# Prediction value 0.6037194132804871
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 79ms/step
# Prediction index 0
# Prediction value 0.7821934819221497
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7488706707954407
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 69ms/step
# Prediction index 0
# Prediction value 0.7957987189292908
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 61ms/step
# Prediction index 1
# Prediction value 0.6319966912269592
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 72ms/step
# Prediction index 1
# Prediction value 0.5337711572647095
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 65ms/step
# Prediction index 0
# Prediction value 0.9261901378631592
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 81ms/step
# Prediction index 0
# Prediction value 0.8423454165458679
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 63ms/step
# Prediction index 1
# Prediction value 0.5967068672180176
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 1
# Prediction value 0.8564782738685608
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 1
# Prediction value 0.5708338618278503
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 67ms/step
# Prediction index 0
# Prediction value 0.7574892044067383
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.9012110829353333
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 74ms/step
# Prediction index 0
# Prediction value 0.7290588617324829
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 64ms/step
# Prediction index 0
# Prediction value 0.8008275628089905
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 82ms/step
# Prediction index 0
# Prediction value 0.9735459089279175
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 62ms/step
# Prediction index 0
# Prediction value 0.9112395644187927
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 66ms/step
# Prediction index 0
# Prediction value 0.7834450006484985
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 73ms/step
# Prediction index 0
# Prediction value 0.5472795963287354
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 96ms/step
# Prediction index 0
# Prediction value 0.6320330500602722
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 117ms/step
# Prediction index 0
# Prediction value 0.7296401262283325
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 113ms/step
# Prediction index 0
# Prediction value 0.9384695887565613
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 108ms/step
# Prediction index 0
# Prediction value 0.7306175231933594
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 138ms/step
# Prediction index 0
# Prediction value 0.7119829654693604
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 116ms/step
# Prediction index 0
# Prediction value 0.5533300042152405
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 117ms/step
# Prediction index 0
# Prediction value 0.792218029499054
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 121ms/step
# Prediction index 0
# Prediction value 0.9171172380447388
# ---------------- Not smiling ----------------
# 1/1 [==============================] - 0s 124ms/step
# Prediction index 0
# Prediction value 0.710691511631012
# ---------------- Not smiling ----------------
# ------------------ Continuous analysis ------------------
#
#
# For the first 10 seconds of the video the result is:
# For this segment of the video IS smiling
#
# For the last 10 of the video the result is:
# For this segment of the video IS smiling
# 84.52037501335144
